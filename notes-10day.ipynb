# %% [markdown]
# **DAY 6**

# %%
#TASKS
# 1. Load the data from csv

# %%
import pandas as pd
df1 = pd.read_csv('../input/solar-power-generation-data/Plant_1_Generation_Data.csv')
df2 = pd.read_csv('../input/solar-power-generation-data/Plant_1_Weather_Sensor_Data.csv')

# %%
df1
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0      15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1      15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2      15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3      15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4      15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                 ...       ...              ...       ...       ...
# 68773  17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774  17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775  17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776  17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777  17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 0            0.000    6259559.0
# 1            0.000    6183645.0
# 2            0.000    6987759.0
# 3            0.000    7602960.0
# 4            0.000    7158964.0
# ...            ...          ...
# 68773     5967.000    7287002.0
# 68774     5147.625    7028601.0
# 68775     5819.000    7251204.0
# 68776     5817.000    6583369.0
# 68777     5910.000    7363272.0
#
# [68778 rows x 7 columns]

# %%
df2
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0     2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1     2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2     2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3     2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4     2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                   ...       ...              ...                  ...
# 3177  2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178  2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179  2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180  2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181  2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              22.857507          0.0
# 1              22.761668          0.0
# 2              22.592306          0.0
# 3              22.360852          0.0
# 4              22.165423          0.0
# ...                  ...          ...
# 3177           21.480377          0.0
# 3178           21.389024          0.0
# 3179           20.709211          0.0
# 3180           20.734963          0.0
# 3181           20.427972          0.0
#
# [3182 rows x 6 columns]

# %%
df1.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
df2.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
df1['DATE_TIME'] = pd.to_datetime(df1['DATE_TIME'],format = '%d-%m-%Y %H:%M')   #datetime 
df1['DATE'] = pd.to_datetime(df1['DATE_TIME'],format = '%d-%m-%Y %H:%M').dt.date   #split
df1['DATE'] = pd.to_datetime(df1['DATE'] )      #datetime series
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  datetime64[ns]
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  object
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
#  7   DATE         68778 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(1), object(1)
# memory usage: 4.2+ MB

# %%
df2['DATE_TIME'] = pd.to_datetime(df2['DATE_TIME'],format = '%Y-%m-%d %H:%M')   #datetime 
df2['DATE'] = pd.to_datetime(df2['DATE_TIME'],format = '%Y-%m-%d %H:%M').dt.date   #split
df2['DATE'] = pd.to_datetime(df2['DATE'] )      #datetime series
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   datetime64[ns]
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
#  6   DATE                 3182 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(1), object(1)
# memory usage: 174.1+ KB

# %% [markdown]
# **Explore each dataset - columns, counts, basic stats**

# %%
df1.columns
# Out:
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER',
#        'DAILY_YIELD', 'TOTAL_YIELD', 'DATE'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'AMBIENT_TEMPERATURE',
#        'MODULE_TEMPERATURE', 'IRRADIATION', 'DATE'],
#       dtype='object')

# %%
df1.nunique()
# Out:
# DATE_TIME       3158
# PLANT_ID           1
# SOURCE_KEY        22
# DC_POWER       32909
# AC_POWER       32686
# DAILY_YIELD    29900
# TOTAL_YIELD    37267
# DATE              34
# dtype: int64

# %%
df2.nunique()
# Out:
# DATE_TIME              3182
# PLANT_ID                  1
# SOURCE_KEY                1
# AMBIENT_TEMPERATURE    3182
# MODULE_TEMPERATURE     3182
# IRRADIATION            1758
# DATE                     34
# dtype: int64

# %%
df1.describe()
# Out:
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    68778.0  68778.000000  68778.000000  68778.000000  6.877800e+04
# mean   4135001.0   3147.426211    307.802752   3295.968737  6.978712e+06
# std          0.0   4036.457169    394.396439   3145.178309  4.162720e+05
# min    4135001.0      0.000000      0.000000      0.000000  6.183645e+06
# 25%    4135001.0      0.000000      0.000000      0.000000  6.512003e+06
# 50%    4135001.0    429.000000     41.493750   2658.714286  7.146685e+06
# 75%    4135001.0   6366.964286    623.618750   6274.000000  7.268706e+06
# max    4135001.0  14471.125000   1410.950000   9163.000000  7.846821e+06

# %%
df2.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3182.0          3182.000000         3182.000000  3182.000000
# mean   4135001.0            25.531606           31.091015     0.228313
# std          0.0             3.354856           12.261222     0.300836
# min    4135001.0            20.398505           18.140415     0.000000
# 25%    4135001.0            22.705182           21.090553     0.000000
# 50%    4135001.0            24.613814           24.618060     0.024653
# 75%    4135001.0            27.920532           41.307840     0.449588
# max    4135001.0            35.252486           65.545714     1.221652

# %% [markdown]
# # **What is the mean value of daily yield?**

# %%
dy_mean = df1['DAILY_YIELD'].mean()
print(f'The mean value of Daily Yield is {dy_mean}')
# Out:
# The mean value of Daily Yield is 3295.968737182587

# %% [markdown]
# **What is the total irradiation per day?
# # **

# %%
df2['IRRADIATION'].sum()
# Out:
# 726.4914252689023

# %%
df2.groupby('DATE')["IRRADIATION"].sum()
# Out:
# DATE
# 2020-05-15    19.037010
# 2020-05-16    18.651690
# 2020-05-17    22.931378
# 2020-05-18    15.266485
# 2020-05-19    18.044861
# 2020-05-20    18.245542
# 2020-05-21    23.556170
# 2020-05-22    22.119123
# 2020-05-23    26.106652
# 2020-05-24    24.937180
# 2020-05-25    27.233366
# 2020-05-26    24.250589
# 2020-05-27    20.537566
# 2020-05-28    26.032384
# 2020-05-29    24.795661
# 2020-05-30    21.875054
# 2020-05-31    17.625458
# 2020-06-01    17.649244
# 2020-06-02    21.483649
# 2020-06-03    21.927709
# 2020-06-04    24.670974
# 2020-06-05    23.192659
# 2020-06-06    19.526878
# 2020-06-07    24.402373
# 2020-06-08    25.315527
# 2020-06-09    24.754673
# 2020-06-10    19.232292
# 2020-06-11    15.533706
# 2020-06-12    16.301551
# 2020-06-13    25.389355
# 2020-06-14    21.128221
# 2020-06-15    19.768806
# 2020-06-16    17.979125
# 2020-06-17    16.988513
# Name: IRRADIATION, dtype: float64

# %% [markdown]
#  **What is the max ambient and module temperature?
# **

# %%
df2['AMBIENT_TEMPERATURE'].max()
# Out:
# 35.25248613333334

# %%
df2['MODULE_TEMPERATURE'].max()
# Out:
# 65.54571366666664

# %% [markdown]
# **How many inverters are there for each plant?
# **

# %%
df1['SOURCE_KEY'].nunique()
# Out:
# 22

# %% [markdown]
# **What is the maximum/minimum amount of DC/AC Power generated in a time interval/day?
# **

# %%
df1['DC_POWER'].max()
# Out:
# 14471.125

# %%
df1['DC_POWER'].min()
# Out:
# 0.0

# %%
df1['AC_POWER'].max()
# Out:
# 1410.95

# %%
df1['AC_POWER'].min()
# Out:
# 0.0

# %%
a = df1.groupby('DATE')["DC_POWER"].min()
print(a)
# Out:
# DATE
# 2020-05-15    0.0
# 2020-05-16    0.0
# 2020-05-17    0.0
# 2020-05-18    0.0
# 2020-05-19    0.0
# 2020-05-20    0.0
# 2020-05-21    0.0
# 2020-05-22    0.0
# 2020-05-23    0.0
# 2020-05-24    0.0
# 2020-05-25    0.0
# 2020-05-26    0.0
# 2020-05-27    0.0
# 2020-05-28    0.0
# 2020-05-29    0.0
# 2020-05-30    0.0
# 2020-05-31    0.0
# 2020-06-01    0.0
# 2020-06-02    0.0
# 2020-06-03    0.0
# 2020-06-04    0.0
# 2020-06-05    0.0
# 2020-06-06    0.0
# 2020-06-07    0.0
# 2020-06-08    0.0
# 2020-06-09    0.0
# 2020-06-10    0.0
# 2020-06-11    0.0
# 2020-06-12    0.0
# 2020-06-13    0.0
# 2020-06-14    0.0
# 2020-06-15    0.0
# 2020-06-16    0.0
# 2020-06-17    0.0
# Name: DC_POWER, dtype: float64

# %%
b = df1.groupby('DATE')["DC_POWER"].max()
print(b)
# Out:
# DATE
# 2020-05-15    12319.14286
# 2020-05-16    11986.57143
# 2020-05-17    13217.42857
# 2020-05-18    13382.75000
# 2020-05-19    11911.50000
# 2020-05-20    13241.14286
# 2020-05-21    14038.28571
# 2020-05-22    14300.28571
# 2020-05-23    13848.00000
# 2020-05-24    13286.14286
# 2020-05-25    13060.71429
# 2020-05-26    13434.42857
# 2020-05-27    13402.87500
# 2020-05-28    13810.57143
# 2020-05-29    13236.57143
# 2020-05-30    14224.85714
# 2020-05-31    13774.14286
# 2020-06-01    14019.25000
# 2020-06-02    13579.57143
# 2020-06-03    13579.42857
# 2020-06-04    14413.42857
# 2020-06-05    13598.57143
# 2020-06-06    13958.14286
# 2020-06-07    14091.71429
# 2020-06-08    13326.00000
# 2020-06-09    13702.71429
# 2020-06-10    13907.85714
# 2020-06-11    11249.42857
# 2020-06-12    10813.14286
# 2020-06-13    13743.37500
# 2020-06-14    14471.12500
# 2020-06-15    12640.00000
# 2020-06-16    12351.00000
# 2020-06-17    13869.57143
# Name: DC_POWER, dtype: float64

# %%
c = df1.groupby('DATE')["AC_POWER"].max()
print(c)
# Out:
# DATE
# 2020-05-15    1201.442857
# 2020-05-16    1168.842857
# 2020-05-17    1288.900000
# 2020-05-18    1304.825000
# 2020-05-19    1162.600000
# 2020-05-20    1291.000000
# 2020-05-21    1368.700000
# 2020-05-22    1394.285714
# 2020-05-23    1350.214286
# 2020-05-24    1295.414286
# 2020-05-25    1273.428571
# 2020-05-26    1309.857143
# 2020-05-27    1306.787500
# 2020-05-28    1346.500000
# 2020-05-29    1290.571429
# 2020-05-30    1386.942857
# 2020-05-31    1342.985714
# 2020-06-01    1366.887500
# 2020-06-02    1324.200000
# 2020-06-03    1324.000000
# 2020-06-04    1405.300000
# 2020-06-05    1325.871429
# 2020-06-06    1360.914286
# 2020-06-07    1373.928571
# 2020-06-08    1299.275000
# 2020-06-09    1336.000000
# 2020-06-10    1356.000000
# 2020-06-11    1098.328571
# 2020-06-12    1056.271429
# 2020-06-13    1339.962500
# 2020-06-14    1410.950000
# 2020-06-15    1232.814286
# 2020-06-16    1205.042857
# 2020-06-17    1352.271429
# Name: AC_POWER, dtype: float64

# %%
d = df1.groupby('DATE')["AC_POWER"].min()
print(d)
# Out:
# DATE
# 2020-05-15    0.0
# 2020-05-16    0.0
# 2020-05-17    0.0
# 2020-05-18    0.0
# 2020-05-19    0.0
# 2020-05-20    0.0
# 2020-05-21    0.0
# 2020-05-22    0.0
# 2020-05-23    0.0
# 2020-05-24    0.0
# 2020-05-25    0.0
# 2020-05-26    0.0
# 2020-05-27    0.0
# 2020-05-28    0.0
# 2020-05-29    0.0
# 2020-05-30    0.0
# 2020-05-31    0.0
# 2020-06-01    0.0
# 2020-06-02    0.0
# 2020-06-03    0.0
# 2020-06-04    0.0
# 2020-06-05    0.0
# 2020-06-06    0.0
# 2020-06-07    0.0
# 2020-06-08    0.0
# 2020-06-09    0.0
# 2020-06-10    0.0
# 2020-06-11    0.0
# 2020-06-12    0.0
# 2020-06-13    0.0
# 2020-06-14    0.0
# 2020-06-15    0.0
# 2020-06-16    0.0
# 2020-06-17    0.0
# Name: AC_POWER, dtype: float64

# %% [markdown]
# # **Which inverter (source_key) has produced maximum DC/AC power?
# **

# %%
df1[df1['DC_POWER'] == df1['DC_POWER'].max()]['SOURCE_KEY']
# Out:
# 61624    wCURE6d3bPkepu2
# Name: SOURCE_KEY, dtype: object

# %% [markdown]
# # Rank the inverters based on the DC/AC power they produce

# %%
s= df1.groupby('SOURCE_KEY').sum()
s['AC_POWER'].sort_values()
# Out:
# SOURCE_KEY
# bvBOhCH3iADSZry    873237.550835
# 1BY6WEcLGh8j5v7    886665.326069
# ih0vzX44oOqAx2f    948272.430359
# z9Y9gH1T5YWrNuG    958094.071906
# ZoEaEvLYb1n2sOq    958700.484522
# 7JYdWkrLSPkdwr4    959906.307338
# zBIq5rxdHJRwDNY    960419.146543
# sjndEbLyjtCKgGv    961917.916550
# WRmjgnKYAwPKWDb    962138.298813
# YxYtjZvoooNbGkE    965127.756186
# rGa61gmuvPhdLxV    966395.835123
# pkci93gMrogZuBj    967719.414521
# wCURE6d3bPkepu2    969260.200356
# zVJPv84UY57bAof    973677.901192
# uHbuxQJl8lW7ozc    976462.011390
# iCRJl6heRkivqQ3    976688.499523
# ZnxXDlPa8U1GXgE    977644.316190
# McdE0feGgRqW7Ca    981080.708217
# 3PZuoBAID5Wc2HD    982068.208928
# VHMLBKoKgIrUVDU    983449.000642
# 1IF53ai7Xc0U56Y    984007.153452
# adLQvlD726eNBSB    997125.156663
# Name: AC_POWER, dtype: float64

# %%
q= df1.groupby('SOURCE_KEY').sum()
q['DC_POWER'].sort_values()
# Out:
# SOURCE_KEY
# bvBOhCH3iADSZry    8.925490e+06
# 1BY6WEcLGh8j5v7    9.063716e+06
# ih0vzX44oOqAx2f    9.695845e+06
# z9Y9gH1T5YWrNuG    9.797002e+06
# ZoEaEvLYb1n2sOq    9.803128e+06
# 7JYdWkrLSPkdwr4    9.815350e+06
# zBIq5rxdHJRwDNY    9.820452e+06
# sjndEbLyjtCKgGv    9.835197e+06
# WRmjgnKYAwPKWDb    9.838489e+06
# YxYtjZvoooNbGkE    9.869145e+06
# rGa61gmuvPhdLxV    9.881965e+06
# pkci93gMrogZuBj    9.895623e+06
# wCURE6d3bPkepu2    9.911622e+06
# zVJPv84UY57bAof    9.956927e+06
# uHbuxQJl8lW7ozc    9.985363e+06
# iCRJl6heRkivqQ3    9.987733e+06
# ZnxXDlPa8U1GXgE    9.997405e+06
# McdE0feGgRqW7Ca    1.003212e+07
# 3PZuoBAID5Wc2HD    1.004313e+07
# VHMLBKoKgIrUVDU    1.005725e+07
# 1IF53ai7Xc0U56Y    1.006294e+07
# adLQvlD726eNBSB    1.019778e+07
# Name: DC_POWER, dtype: float64

# %% [markdown]
# # Is there any missing data?

# %%
#Yes
22*4*24
# Out:
# 2112

# %%
df1
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0     2020-05-15 00:00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1     2020-05-15 00:00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2     2020-05-15 00:00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3     2020-05-15 00:00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4     2020-05-15 00:00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                   ...       ...              ...       ...       ...
# 68773 2020-06-17 23:45:00   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774 2020-06-17 23:45:00   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775 2020-06-17 23:45:00   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776 2020-06-17 23:45:00   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777 2020-06-17 23:45:00   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD       DATE
# 0            0.000    6259559.0 2020-05-15
# 1            0.000    6183645.0 2020-05-15
# 2            0.000    6987759.0 2020-05-15
# 3            0.000    7602960.0 2020-05-15
# 4            0.000    7158964.0 2020-05-15
# ...            ...          ...        ...
# 68773     5967.000    7287002.0 2020-06-17
# 68774     5147.625    7028601.0 2020-06-17
# 68775     5819.000    7251204.0 2020-06-17
# 68776     5817.000    6583369.0 2020-06-17
# 68777     5910.000    7363272.0 2020-06-17
#
# [68778 rows x 8 columns]

# %%
df1['DATE'].value_counts()
# Out:
# 2020-05-18    2112
# 2020-06-14    2112
# 2020-06-01    2112
# 2020-05-30    2112
# 2020-06-08    2112
# 2020-06-15    2112
# 2020-06-11    2112
# 2020-06-10    2112
# 2020-06-12    2112
# 2020-05-17    2112
# 2020-06-16    2112
# 2020-06-09    2112
# 2020-05-24    2112
# 2020-06-13    2112
# 2020-06-07    2112
# 2020-05-31    2106
# 2020-06-03    2094
# 2020-06-02    2088
# 2020-06-05    2080
# 2020-05-26    2072
# 2020-06-17    2068
# 2020-05-25    2060
# 2020-06-04    2052
# 2020-06-06    2052
# 2020-05-27    2052
# 2020-05-22    2028
# 2020-05-19    1990
# 2020-05-28    1980
# 2020-05-23    1958
# 2020-05-15    1954
# 2020-05-16    1934
# 2020-05-20    1672
# 2020-05-29    1490
# 2020-05-21    1368
# Name: DATE, dtype: int64

# %% [markdown]
# # Visualization

# %%
import pandas as pd

df2 = pd.read_csv('../input/solar-power-generation-data/Plant_1_Weather_Sensor_Data.csv')
df2
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0     2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1     2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2     2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3     2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4     2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                   ...       ...              ...                  ...
# 3177  2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178  2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179  2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180  2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181  2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              22.857507          0.0
# 1              22.761668          0.0
# 2              22.592306          0.0
# 3              22.360852          0.0
# 4              22.165423          0.0
# ...                  ...          ...
# 3177           21.480377          0.0
# 3178           21.389024          0.0
# 3179           20.709211          0.0
# 3180           20.734963          0.0
# 3181           20.427972          0.0
#
# [3182 rows x 6 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   object
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 149.3+ KB

# %%
df2['DATE_TIME'] = pd.to_datetime(df2['DATE_TIME'],format = '%Y-%m-%d %H:%M')   #datetime 
df2['DATE_TIME']
# Out:
# 0      2020-05-15 00:00:00
# 1      2020-05-15 00:15:00
# 2      2020-05-15 00:30:00
# 3      2020-05-15 00:45:00
# 4      2020-05-15 01:00:00
#                ...
# 3177   2020-06-17 22:45:00
# 3178   2020-06-17 23:00:00
# 3179   2020-06-17 23:15:00
# 3180   2020-06-17 23:30:00
# 3181   2020-06-17 23:45:00
# Name: DATE_TIME, Length: 3182, dtype: datetime64[ns]

# %%
import matplotlib.pyplot as plt

# %%
#module temp daily basis
plt.figure(figsize=(20,10))
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE'],label ='Module Temperature')
plt.legend()
plt.xlabel('DATE TIME')
plt.ylabel('MODULE TEMPERATURE')
plt.xticks(rotation = 90)
plt.grid()
plt.margins(0.05)
plt.title("Module VS Date_time")
plt.show()

# %%
#ambient temp daily basis
plt.figure(figsize=(20,10))
plt.plot(df2['DATE_TIME'],df2['AMBIENT_TEMPERATURE'],label ='Ambient Temperature')
plt.legend()
plt.xlabel('DATE TIME')
plt.ylabel('AMBIENT TEMPERATURE')
plt.xticks(rotation = 90)
plt.grid()
plt.margins(0.05)
plt.title("Ambient VS Date_time")
plt.show()

# %%
#Difference in Temp 
plt.figure(figsize=(20,10))
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE']-df2['AMBIENT_TEMPERATURE'], label ='Difference' , c ='r')
plt.legend()
plt.xlabel('DATE TIME')
plt.ylabel('MODULE - AMBIENT ')
plt.xticks(rotation = 90)
plt.grid()
plt.margins(0.05)
plt.title("Module - Ambient VS Date_time")
plt.show()

# %%
#RED for ambient   # Blue for module   # black for Difference 
plt.figure(figsize=(20,10))
plt.plot(df2['DATE_TIME'],df2['AMBIENT_TEMPERATURE'], label ='AMBIENT' , c ='r')
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE'], label ='MODULE' )
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE']-df2['AMBIENT_TEMPERATURE'], label ='Difference' , c ='k')
plt.legend()
plt.grid()
plt.show()

# %%
#RED for ambient   # Blue for module   # black for Difference 
plt.figure(figsize=(20,10))
plt.plot(df2['DATE_TIME'],df2['AMBIENT_TEMPERATURE'].rolling(window=20).mean(), label ='AMBIENT' , c ='r')
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE'].rolling(window=20).mean(), label ='MODULE' )
plt.plot(df2['DATE_TIME'],(df2['MODULE_TEMPERATURE']-df2['AMBIENT_TEMPERATURE']).rolling(window=20).mean(), label ='Difference' , c ='k')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
a = np.random.randint(1,500,250)
b = np.random.randint(500,1000,250)
plt.plot(a,b, marker ='o' ,linestyle ='')
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.plot(df2['AMBIENT_TEMPERATURE'],df2['MODULE_TEMPERATURE'],marker = 'o' ,linestyle = '', alpha = 0.5, ms=10)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   datetime64[ns]
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 149.3+ KB

# %%
df2['DATE'] = pd.to_datetime(df2['DATE_TIME'],format = '%Y-%m-%d %H:%M').dt.date
df2['DATE'] = pd.to_datetime(df2['DATE'])

# %%
dates =df2['DATE'].unique()
dates
# Out:
# array(['2020-05-15T00:00:00.000000000', '2020-05-16T00:00:00.000000000',
#        '2020-05-17T00:00:00.000000000', '2020-05-18T00:00:00.000000000',
#        '2020-05-19T00:00:00.000000000', '2020-05-20T00:00:00.000000000',
#        '2020-05-21T00:00:00.000000000', '2020-05-22T00:00:00.000000000',
#        '2020-05-23T00:00:00.000000000', '2020-05-24T00:00:00.000000000',
#        '2020-05-25T00:00:00.000000000', '2020-05-26T00:00:00.000000000',
#        '2020-05-27T00:00:00.000000000', '2020-05-28T00:00:00.000000000',
#        '2020-05-29T00:00:00.000000000', '2020-05-30T00:00:00.000000000',
#        '2020-05-31T00:00:00.000000000', '2020-06-01T00:00:00.000000000',
#        '2020-06-02T00:00:00.000000000', '2020-06-03T00:00:00.000000000',
#        '2020-06-04T00:00:00.000000000', '2020-06-05T00:00:00.000000000',
#        '2020-06-06T00:00:00.000000000', '2020-06-07T00:00:00.000000000',
#        '2020-06-08T00:00:00.000000000', '2020-06-09T00:00:00.000000000',
#        '2020-06-10T00:00:00.000000000', '2020-06-11T00:00:00.000000000',
#        '2020-06-12T00:00:00.000000000', '2020-06-13T00:00:00.000000000',
#        '2020-06-14T00:00:00.000000000', '2020-06-15T00:00:00.000000000',
#        '2020-06-16T00:00:00.000000000', '2020-06-17T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
dates[0]
# Out:
# numpy.datetime64('2020-05-15T00:00:00.000000000')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   datetime64[ns]
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
#  6   DATE                 3182 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(1), object(1)
# memory usage: 174.1+ KB

# %%
#plot irradiation > 0 
data = df2[df2['DATE']==dates[0]][df2['IRRADIATION']>0]
data
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 23 2020-05-15 05:45:00   4135001  HmiyD2TTLFNqkNe            24.289211
# 24 2020-05-15 06:00:00   4135001  HmiyD2TTLFNqkNe            24.088446
# 25 2020-05-15 06:15:00   4135001  HmiyD2TTLFNqkNe            24.011635
# 26 2020-05-15 06:30:00   4135001  HmiyD2TTLFNqkNe            23.976731
# 27 2020-05-15 06:45:00   4135001  HmiyD2TTLFNqkNe            24.218990
# 28 2020-05-15 07:00:00   4135001  HmiyD2TTLFNqkNe            24.537398
# 29 2020-05-15 07:15:00   4135001  HmiyD2TTLFNqkNe            24.815960
# 30 2020-05-15 07:30:00   4135001  HmiyD2TTLFNqkNe            24.988790
# 31 2020-05-15 07:45:00   4135001  HmiyD2TTLFNqkNe            25.216180
# 32 2020-05-15 08:00:00   4135001  HmiyD2TTLFNqkNe            25.419513
# 33 2020-05-15 08:15:00   4135001  HmiyD2TTLFNqkNe            25.959082
# 34 2020-05-15 08:30:00   4135001  HmiyD2TTLFNqkNe            26.430782
# 35 2020-05-15 08:45:00   4135001  HmiyD2TTLFNqkNe            26.831830
# 36 2020-05-15 09:00:00   4135001  HmiyD2TTLFNqkNe            27.620970
# 37 2020-05-15 09:15:00   4135001  HmiyD2TTLFNqkNe            27.988362
# 38 2020-05-15 09:30:00   4135001  HmiyD2TTLFNqkNe            27.516728
# 39 2020-05-15 09:45:00   4135001  HmiyD2TTLFNqkNe            27.450108
# 40 2020-05-15 10:00:00   4135001  HmiyD2TTLFNqkNe            28.632192
# 41 2020-05-15 10:15:00   4135001  HmiyD2TTLFNqkNe            28.768913
# 42 2020-05-15 10:30:00   4135001  HmiyD2TTLFNqkNe            29.351443
# 43 2020-05-15 10:45:00   4135001  HmiyD2TTLFNqkNe            28.854708
# 44 2020-05-15 11:00:00   4135001  HmiyD2TTLFNqkNe            29.410819
# 45 2020-05-15 11:15:00   4135001  HmiyD2TTLFNqkNe            30.216062
# 46 2020-05-15 11:30:00   4135001  HmiyD2TTLFNqkNe            30.287073
# 47 2020-05-15 11:45:00   4135001  HmiyD2TTLFNqkNe            30.811049
# 48 2020-05-15 12:00:00   4135001  HmiyD2TTLFNqkNe            31.305375
# 49 2020-05-15 12:15:00   4135001  HmiyD2TTLFNqkNe            31.507298
# 50 2020-05-15 12:30:00   4135001  HmiyD2TTLFNqkNe            32.147685
# 51 2020-05-15 12:45:00   4135001  HmiyD2TTLFNqkNe            32.391420
# 52 2020-05-15 13:00:00   4135001  HmiyD2TTLFNqkNe            32.622796
# 53 2020-05-15 13:15:00   4135001  HmiyD2TTLFNqkNe            32.497064
# 54 2020-05-15 13:30:00   4135001  HmiyD2TTLFNqkNe            32.524621
# 55 2020-05-15 13:45:00   4135001  HmiyD2TTLFNqkNe            32.678471
# 56 2020-05-15 14:00:00   4135001  HmiyD2TTLFNqkNe            33.763185
# 57 2020-05-15 14:15:00   4135001  HmiyD2TTLFNqkNe            34.130770
# 58 2020-05-15 14:30:00   4135001  HmiyD2TTLFNqkNe            34.081384
# 59 2020-05-15 14:45:00   4135001  HmiyD2TTLFNqkNe            33.695722
# 60 2020-05-15 15:00:00   4135001  HmiyD2TTLFNqkNe            33.890576
# 61 2020-05-15 15:15:00   4135001  HmiyD2TTLFNqkNe            34.043744
# 62 2020-05-15 15:30:00   4135001  HmiyD2TTLFNqkNe            34.402852
# 63 2020-05-15 15:45:00   4135001  HmiyD2TTLFNqkNe            34.430943
# 64 2020-05-15 16:00:00   4135001  HmiyD2TTLFNqkNe            34.381150
# 65 2020-05-15 16:15:00   4135001  HmiyD2TTLFNqkNe            34.126257
# 66 2020-05-15 16:30:00   4135001  HmiyD2TTLFNqkNe            34.356610
# 67 2020-05-15 16:45:00   4135001  HmiyD2TTLFNqkNe            33.861597
# 68 2020-05-15 17:00:00   4135001  HmiyD2TTLFNqkNe            33.443314
# 69 2020-05-15 17:15:00   4135001  HmiyD2TTLFNqkNe            33.300255
# 70 2020-05-15 17:30:00   4135001  HmiyD2TTLFNqkNe            33.032122
# 71 2020-05-15 17:45:00   4135001  HmiyD2TTLFNqkNe            32.311871
# 72 2020-05-15 18:00:00   4135001  HmiyD2TTLFNqkNe            31.132414
# 73 2020-05-15 18:15:00   4135001  HmiyD2TTLFNqkNe            29.243111
# 74 2020-05-15 18:30:00   4135001  HmiyD2TTLFNqkNe            28.495518
# 78 2020-05-15 19:30:00   4135001  HmiyD2TTLFNqkNe            27.018701
# 79 2020-05-15 19:45:00   4135001  HmiyD2TTLFNqkNe            23.787237
#
#     MODULE_TEMPERATURE  IRRADIATION       DATE
# 23           23.096692     0.000863 2020-05-15
# 24           22.206757     0.005887 2020-05-15
# 25           22.353459     0.022282 2020-05-15
# 26           22.893282     0.049410 2020-05-15
# 27           24.442444     0.095394 2020-05-15
# 28           27.185653     0.141940 2020-05-15
# 29           28.888478     0.154713 2020-05-15
# 30           29.605644     0.148799 2020-05-15
# 31           29.547111     0.144793 2020-05-15
# 32           31.412545     0.201639 2020-05-15
# 33           35.528711     0.345708 2020-05-15
# 34           40.318059     0.405349 2020-05-15
# 35           39.081954     0.312427 2020-05-15
# 36           45.009233     0.623153 2020-05-15
# 37           46.617706     0.344884 2020-05-15
# 38           39.136326     0.249248 2020-05-15
# 39           40.930577     0.541206 2020-05-15
# 40           52.547736     0.670675 2020-05-15
# 41           47.633738     0.572283 2020-05-15
# 42           49.249723     0.455148 2020-05-15
# 43           44.048326     0.361962 2020-05-15
# 44           47.685453     0.636561 2020-05-15
# 45           50.006989     0.585787 2020-05-15
# 46           49.841364     0.557069 2020-05-15
# 47           47.836383     0.467987 2020-05-15
# 48           49.183584     0.514963 2020-05-15
# 49           49.844493     0.787866 2020-05-15
# 50           52.353255     0.649248 2020-05-15
# 51           50.631240     0.761243 2020-05-15
# 52           49.610768     0.416035 2020-05-15
# 53           47.011161     0.489244 2020-05-15
# 54           46.669863     0.574561 2020-05-15
# 55           47.516884     0.560986 2020-05-15
# 56           49.803904     0.735083 2020-05-15
# 57           55.030613     0.893661 2020-05-15
# 58           54.519137     0.466789 2020-05-15
# 59           47.618195     0.542138 2020-05-15
# 60           46.029081     0.398889 2020-05-15
# 61           44.286092     0.447292 2020-05-15
# 62           46.744281     0.565196 2020-05-15
# 63           43.920616     0.346231 2020-05-15
# 64           43.332853     0.358182 2020-05-15
# 65           41.007432     0.328896 2020-05-15
# 66           41.280591     0.344954 2020-05-15
# 67           39.419076     0.260347 2020-05-15
# 68           36.826704     0.166813 2020-05-15
# 69           35.852207     0.173899 2020-05-15
# 70           34.338400     0.087162 2020-05-15
# 71           31.548539     0.038403 2020-05-15
# 72           30.225331     0.022545 2020-05-15
# 73           28.682507     0.009150 2020-05-15
# 74           27.285992     0.001841 2020-05-15
# 78           25.745268     0.000125 2020-05-15
# 79           22.511406     0.000100 2020-05-15

# %%
data = df2[df2['DATE']==dates[0]][df2['IRRADIATION']>0]
plt.plot(data['AMBIENT_TEMPERATURE'],data['MODULE_TEMPERATURE'], marker = 'o', linestyle ='', alpha = 0.5, label = pd.to_datetime(date,format = '%Y-%m-%d').date())

plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-b6b2be070a05> in <module>
#       1 data = df2[df2['DATE']==dates[0]][df2['IRRADIATION']>0]
# ----> 2 plt.plot(data['AMBIENT_TEMPERATURE'],data['MODULE_TEMPERATURE'], marker = 'o', linestyle ='', alpha = 0.5, label = pd.to_datetime(date,format = '%Y-%m-%d').date())
#       3
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 'date' is not defined

# %%
plt.figure(figsize=(19,9))
for date in dates:
    data = df2[df2['DATE']==date][df2['IRRADIATION']>0]
    plt.plot(data['AMBIENT_TEMPERATURE'],data['MODULE_TEMPERATURE'], marker = 'o', linestyle ='', alpha = 0.5, ms= 6,label = pd.to_datetime(date,format = '%Y-%m-%d').date())

plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # DAY 7

# %%
df2.columns
# Out:
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'AMBIENT_TEMPERATURE',
#        'MODULE_TEMPERATURE', 'IRRADIATION', 'DATE'],
#       dtype='object')

# %%
df2
# Out:
#                DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0    2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1    2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2    2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3    2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4    2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                  ...       ...              ...                  ...
# 3177 2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178 2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179 2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180 2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181 2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION       DATE
# 0              22.857507          0.0 2020-05-15
# 1              22.761668          0.0 2020-05-15
# 2              22.592306          0.0 2020-05-15
# 3              22.360852          0.0 2020-05-15
# 4              22.165423          0.0 2020-05-15
# ...                  ...          ...        ...
# 3177           21.480377          0.0 2020-06-17
# 3178           21.389024          0.0 2020-06-17
# 3179           20.709211          0.0 2020-06-17
# 3180           20.734963          0.0 2020-06-17
# 3181           20.427972          0.0 2020-06-17
#
# [3182 rows x 7 columns]

# %%
#listing the inverters
inv_lst = df1['SOURCE_KEY'].unique()
inv_lst
# Out:
# array(['1BY6WEcLGh8j5v7', '1IF53ai7Xc0U56Y', '3PZuoBAID5Wc2HD',
#        '7JYdWkrLSPkdwr4', 'McdE0feGgRqW7Ca', 'VHMLBKoKgIrUVDU',
#        'WRmjgnKYAwPKWDb', 'ZnxXDlPa8U1GXgE', 'ZoEaEvLYb1n2sOq',
#        'adLQvlD726eNBSB', 'bvBOhCH3iADSZry', 'iCRJl6heRkivqQ3',
#        'ih0vzX44oOqAx2f', 'pkci93gMrogZuBj', 'rGa61gmuvPhdLxV',
#        'sjndEbLyjtCKgGv', 'uHbuxQJl8lW7ozc', 'wCURE6d3bPkepu2',
#        'z9Y9gH1T5YWrNuG', 'zBIq5rxdHJRwDNY', 'zVJPv84UY57bAof',
#        'YxYtjZvoooNbGkE'], dtype=object)

# %%
#using groupby, max total yield for each inverter

# %%
TOTAL = df1.groupby('SOURCE_KEY')['TOTAL_YIELD'].max()
TOTAL
# Out:
# SOURCE_KEY
# 1BY6WEcLGh8j5v7    6485319.0
# 1IF53ai7Xc0U56Y    6433566.0
# 3PZuoBAID5Wc2HD    7237425.0
# 7JYdWkrLSPkdwr4    7846821.0
# McdE0feGgRqW7Ca    7408587.0
# VHMLBKoKgIrUVDU    7456208.0
# WRmjgnKYAwPKWDb    7273532.0
# YxYtjZvoooNbGkE    7425442.0
# ZnxXDlPa8U1GXgE    6770737.0
# ZoEaEvLYb1n2sOq    7341753.0
# adLQvlD726eNBSB    6524508.0
# bvBOhCH3iADSZry    6539009.0
# iCRJl6heRkivqQ3    7426263.0
# ih0vzX44oOqAx2f    6426129.0
# pkci93gMrogZuBj    7415430.0
# rGa61gmuvPhdLxV    7356897.0
# sjndEbLyjtCKgGv    7261681.0
# uHbuxQJl8lW7ozc    7287002.0
# wCURE6d3bPkepu2    7028601.0
# z9Y9gH1T5YWrNuG    7251204.0
# zBIq5rxdHJRwDNY    6583369.0
# zVJPv84UY57bAof    7363272.0
# Name: TOTAL_YIELD, dtype: float64

# %%
#plot bar graph inverters vs total yield
plt.figure(figsize=(20,10))
plt.bar(inv_lst,TOTAL)
plt.xticks(rotation=90)
plt.show()
#annotate or text

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  datetime64[ns]
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  object
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
#  7   DATE         68778 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(1), object(1)
# memory usage: 4.2+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   datetime64[ns]
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
#  6   DATE                 3182 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(1), object(1)
# memory usage: 174.1+ KB

# %%
#2 Dataframes
#Left  df1 : 68778 rows, 8 columns
#Right  df2 : 3182 rows, 7 columns
#output r_left : 68778 rows × 15 columns 14(15-1)
#LEFT MERGE

# %%
r_left = pd.merge(df1,df2, on ='DATE_TIME', how='left')
r_left
# Out:
#                 DATE_TIME  PLANT_ID_x     SOURCE_KEY_x  DC_POWER  AC_POWER  \
# 0     2020-05-15 00:00:00     4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1     2020-05-15 00:00:00     4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2     2020-05-15 00:00:00     4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3     2020-05-15 00:00:00     4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4     2020-05-15 00:00:00     4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                   ...         ...              ...       ...       ...
# 68773 2020-06-17 23:45:00     4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774 2020-06-17 23:45:00     4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775 2020-06-17 23:45:00     4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776 2020-06-17 23:45:00     4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777 2020-06-17 23:45:00     4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD     DATE_x  PLANT_ID_y     SOURCE_KEY_y  \
# 0            0.000    6259559.0 2020-05-15   4135001.0  HmiyD2TTLFNqkNe
# 1            0.000    6183645.0 2020-05-15   4135001.0  HmiyD2TTLFNqkNe
# 2            0.000    6987759.0 2020-05-15   4135001.0  HmiyD2TTLFNqkNe
# 3            0.000    7602960.0 2020-05-15   4135001.0  HmiyD2TTLFNqkNe
# 4            0.000    7158964.0 2020-05-15   4135001.0  HmiyD2TTLFNqkNe
# ...            ...          ...        ...         ...              ...
# 68773     5967.000    7287002.0 2020-06-17   4135001.0  HmiyD2TTLFNqkNe
# 68774     5147.625    7028601.0 2020-06-17   4135001.0  HmiyD2TTLFNqkNe
# 68775     5819.000    7251204.0 2020-06-17   4135001.0  HmiyD2TTLFNqkNe
# 68776     5817.000    6583369.0 2020-06-17   4135001.0  HmiyD2TTLFNqkNe
# 68777     5910.000    7363272.0 2020-06-17   4135001.0  HmiyD2TTLFNqkNe
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION     DATE_y
# 0                25.184316           22.857507          0.0 2020-05-15
# 1                25.184316           22.857507          0.0 2020-05-15
# 2                25.184316           22.857507          0.0 2020-05-15
# 3                25.184316           22.857507          0.0 2020-05-15
# 4                25.184316           22.857507          0.0 2020-05-15
# ...                    ...                 ...          ...        ...
# 68773            21.909288           20.427972          0.0 2020-06-17
# 68774            21.909288           20.427972          0.0 2020-06-17
# 68775            21.909288           20.427972          0.0 2020-06-17
# 68776            21.909288           20.427972          0.0 2020-06-17
# 68777            21.909288           20.427972          0.0 2020-06-17
#
# [68778 rows x 14 columns]

# %%
r_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68778 entries, 0 to 68777
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            68778 non-null  datetime64[ns]
#  1   PLANT_ID_x           68778 non-null  int64
#  2   SOURCE_KEY_x         68778 non-null  object
#  3   DC_POWER             68778 non-null  float64
#  4   AC_POWER             68778 non-null  float64
#  5   DAILY_YIELD          68778 non-null  float64
#  6   TOTAL_YIELD          68778 non-null  float64
#  7   DATE_x               68778 non-null  datetime64[ns]
#  8   PLANT_ID_y           68774 non-null  float64
#  9   SOURCE_KEY_y         68774 non-null  object
#  10  AMBIENT_TEMPERATURE  68774 non-null  float64
#  11  MODULE_TEMPERATURE   68774 non-null  float64
#  12  IRRADIATION          68774 non-null  float64
#  13  DATE_y               68774 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(8), int64(1), object(2)
# memory usage: 7.9+ MB

# %%
#check the amount null values in merged dataframe
r_left.isnull().sum()
# Out:
# DATE_TIME              0
# PLANT_ID_x             0
# SOURCE_KEY_x           0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# DATE_x                 0
# PLANT_ID_y             4
# SOURCE_KEY_y           4
# AMBIENT_TEMPERATURE    4
# MODULE_TEMPERATURE     4
# IRRADIATION            4
# DATE_y                 4
# dtype: int64

# %%
#ambient temp
r_left['AMBIENT_TEMPERATURE'].isnull().value_counts()
r_left['MODULE_TEMPERATURE'].isnull().value_counts()
r_left['AC_POWER'].isnull().value_counts()
# Out:
# False    68778
# Name: AC_POWER, dtype: int64

# %%
null_data1 = r_left[r_left.isnull().any(axis=1)]
null_data1
# Out:
#                 DATE_TIME  PLANT_ID_x     SOURCE_KEY_x  DC_POWER  AC_POWER  \
# 38544 2020-06-03 14:00:00     4135001  1IF53ai7Xc0U56Y    7003.0     685.8
# 38545 2020-06-03 14:00:00     4135001  adLQvlD726eNBSB    7204.0     705.4
# 38546 2020-06-03 14:00:00     4135001  wCURE6d3bPkepu2    7545.0     738.7
# 38547 2020-06-03 14:00:00     4135001  z9Y9gH1T5YWrNuG    7946.0     777.8
#
#        DAILY_YIELD  TOTAL_YIELD     DATE_x  PLANT_ID_y SOURCE_KEY_y  \
# 38544       5601.0    6330385.0 2020-06-03         NaN          NaN
# 38545       5685.0    6419961.0 2020-06-03         NaN          NaN
# 38546       5579.0    6928448.0 2020-06-03         NaN          NaN
# 38547       5541.0    7152815.0 2020-06-03         NaN          NaN
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION DATE_y
# 38544                  NaN                 NaN          NaN    NaT
# 38545                  NaN                 NaN          NaN    NaT
# 38546                  NaN                 NaN          NaN    NaT
# 38547                  NaN                 NaN          NaN    NaT

# %%
plt.figure(figsize=(20,10))
plt.plot(r_left['IRRADIATION'],r_left['DC_POWER'], marker='o',linestyle='',alpha =0.5,label='DC POWER')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(r_left['MODULE_TEMPERATURE'],r_left['DC_POWER'], marker='o',linestyle='',alpha =0.5,label='DC POWER')
plt.legend()
plt.show()

# %%
dates = r_left['DATE_x'].unique()
dates
# Out:
# array(['2020-05-15T00:00:00.000000000', '2020-05-16T00:00:00.000000000',
#        '2020-05-17T00:00:00.000000000', '2020-05-18T00:00:00.000000000',
#        '2020-05-19T00:00:00.000000000', '2020-05-20T00:00:00.000000000',
#        '2020-05-21T00:00:00.000000000', '2020-05-22T00:00:00.000000000',
#        '2020-05-23T00:00:00.000000000', '2020-05-24T00:00:00.000000000',
#        '2020-05-25T00:00:00.000000000', '2020-05-26T00:00:00.000000000',
#        '2020-05-27T00:00:00.000000000', '2020-05-28T00:00:00.000000000',
#        '2020-05-29T00:00:00.000000000', '2020-05-30T00:00:00.000000000',
#        '2020-05-31T00:00:00.000000000', '2020-06-01T00:00:00.000000000',
#        '2020-06-02T00:00:00.000000000', '2020-06-03T00:00:00.000000000',
#        '2020-06-04T00:00:00.000000000', '2020-06-05T00:00:00.000000000',
#        '2020-06-06T00:00:00.000000000', '2020-06-07T00:00:00.000000000',
#        '2020-06-08T00:00:00.000000000', '2020-06-09T00:00:00.000000000',
#        '2020-06-10T00:00:00.000000000', '2020-06-11T00:00:00.000000000',
#        '2020-06-12T00:00:00.000000000', '2020-06-13T00:00:00.000000000',
#        '2020-06-14T00:00:00.000000000', '2020-06-15T00:00:00.000000000',
#        '2020-06-16T00:00:00.000000000', '2020-06-17T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
r_left[r_left['DATE_x']==dates[0]][r_left['IRRADIATION' ]>0.1]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                DATE_TIME  PLANT_ID_x     SOURCE_KEY_x     DC_POWER  \
# 596  2020-05-15 07:00:00     4135001  1BY6WEcLGh8j5v7  1734.571429
# 597  2020-05-15 07:00:00     4135001  1IF53ai7Xc0U56Y  1990.375000
# 598  2020-05-15 07:00:00     4135001  3PZuoBAID5Wc2HD  1963.375000
# 599  2020-05-15 07:00:00     4135001  7JYdWkrLSPkdwr4  1904.428571
# 600  2020-05-15 07:00:00     4135001  McdE0feGgRqW7Ca  1920.250000
# ...                  ...         ...              ...          ...
# 1515 2020-05-15 17:15:00     4135001  uHbuxQJl8lW7ozc  2357.875000
# 1516 2020-05-15 17:15:00     4135001  wCURE6d3bPkepu2  2284.000000
# 1517 2020-05-15 17:15:00     4135001  z9Y9gH1T5YWrNuG  2274.750000
# 1518 2020-05-15 17:15:00     4135001  zBIq5rxdHJRwDNY  2371.625000
# 1519 2020-05-15 17:15:00     4135001  zVJPv84UY57bAof  2339.375000
#
#         AC_POWER  DAILY_YIELD  TOTAL_YIELD     DATE_x  PLANT_ID_y  \
# 596   170.014286    72.714286  6259631.714 2020-05-15   4135001.0
# 597   195.100000    82.375000  6183727.375 2020-05-15   4135001.0
# 598   192.450000    79.500000  6987838.500 2020-05-15   4135001.0
# 599   186.700000    80.000000  7603040.000 2020-05-15   4135001.0
# 600   188.250000    80.250000  7159044.250 2020-05-15   4135001.0
# ...          ...          ...          ...        ...         ...
# 1515  231.200000  6311.125000  7044992.125 2020-05-15   4135001.0
# 1516  223.937500  6255.500000  6788853.500 2020-05-15   4135001.0
# 1517  223.050000  6313.250000  7014179.250 2020-05-15   4135001.0
# 1518  232.550000  6318.375000  6345698.375 2020-05-15   4135001.0
# 1519  229.387500  5889.250000  7122040.250 2020-05-15   4135001.0
#
#          SOURCE_KEY_y  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION  \
# 596   HmiyD2TTLFNqkNe            24.537398           27.185653     0.141940
# 597   HmiyD2TTLFNqkNe            24.537398           27.185653     0.141940
# 598   HmiyD2TTLFNqkNe            24.537398           27.185653     0.141940
# 599   HmiyD2TTLFNqkNe            24.537398           27.185653     0.141940
# 600   HmiyD2TTLFNqkNe            24.537398           27.185653     0.141940
# ...               ...                  ...                 ...          ...
# 1515  HmiyD2TTLFNqkNe            33.300255           35.852207     0.173899
# 1516  HmiyD2TTLFNqkNe            33.300255           35.852207     0.173899
# 1517  HmiyD2TTLFNqkNe            33.300255           35.852207     0.173899
# 1518  HmiyD2TTLFNqkNe            33.300255           35.852207     0.173899
# 1519  HmiyD2TTLFNqkNe            33.300255           35.852207     0.173899
#
#          DATE_y
# 596  2020-05-15
# 597  2020-05-15
# 598  2020-05-15
# 599  2020-05-15
# 600  2020-05-15
# ...         ...
# 1515 2020-05-15
# 1516 2020-05-15
# 1517 2020-05-15
# 1518 2020-05-15
# 1519 2020-05-15
#
# [924 rows x 14 columns]

# %%
r_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68778 entries, 0 to 68777
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            68778 non-null  datetime64[ns]
#  1   PLANT_ID_x           68778 non-null  int64
#  2   SOURCE_KEY_x         68778 non-null  object
#  3   DC_POWER             68778 non-null  float64
#  4   AC_POWER             68778 non-null  float64
#  5   DAILY_YIELD          68778 non-null  float64
#  6   TOTAL_YIELD          68778 non-null  float64
#  7   DATE_x               68778 non-null  datetime64[ns]
#  8   PLANT_ID_y           68774 non-null  float64
#  9   SOURCE_KEY_y         68774 non-null  object
#  10  AMBIENT_TEMPERATURE  68774 non-null  float64
#  11  MODULE_TEMPERATURE   68774 non-null  float64
#  12  IRRADIATION          68774 non-null  float64
#  13  DATE_y               68774 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(8), int64(1), object(2)
# memory usage: 10.4+ MB

# %%
data = r_left[r_left['DATE_x']==dates[0]][r_left['IRRADIATION' ]>0.1]
plt.plot(data['MODULE_TEMPERATURE'],data['DC_POWER'], marker='o',linestyle='',label = pd.to_datetime(dates[0],format = '%Y-%m-%d').date())
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(20,10))
for date in dates:
    data = r_left[r_left['DATE_x']==date][r_left['IRRADIATION']>0.1]
    plt.plot(data['MODULE_TEMPERATURE'],data['DC_POWER'],marker='o',linestyle='',label = pd.to_datetime(date,format='%Y-%m-%d').date())
plt.legend()
plt.xlabel('Module Temperature')
plt.ylabel('DC Power')
plt.title('MODULE TEMPERATURE VS DC POWER')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_summary = df1.groupby(['SOURCE_KEY','DATE']).agg(READINGS = ('TOTAL_YIELD','count'),  
                                                      INV = ('SOURCE_KEY',max), 
                                                      DATE = ('DATE',max))
data_summary
# Out:
#                             READINGS              INV       DATE
# SOURCE_KEY      DATE
# 1BY6WEcLGh8j5v7 2020-05-15        93  1BY6WEcLGh8j5v7 2020-05-15
#                 2020-05-16        88  1BY6WEcLGh8j5v7 2020-05-16
#                 2020-05-17        96  1BY6WEcLGh8j5v7 2020-05-17
#                 2020-05-18        96  1BY6WEcLGh8j5v7 2020-05-18
#                 2020-05-19        93  1BY6WEcLGh8j5v7 2020-05-19
# ...                              ...              ...        ...
# zVJPv84UY57bAof 2020-06-13        96  zVJPv84UY57bAof 2020-06-13
#                 2020-06-14        96  zVJPv84UY57bAof 2020-06-14
#                 2020-06-15        96  zVJPv84UY57bAof 2020-06-15
#                 2020-06-16        96  zVJPv84UY57bAof 2020-06-16
#                 2020-06-17        94  zVJPv84UY57bAof 2020-06-17
#
# [748 rows x 3 columns]

# %%
r_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68778 entries, 0 to 68777
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            68778 non-null  datetime64[ns]
#  1   PLANT_ID_x           68778 non-null  int64
#  2   SOURCE_KEY_x         68778 non-null  object
#  3   DC_POWER             68778 non-null  float64
#  4   AC_POWER             68778 non-null  float64
#  5   DAILY_YIELD          68778 non-null  float64
#  6   TOTAL_YIELD          68778 non-null  float64
#  7   DATE_x               68778 non-null  datetime64[ns]
#  8   PLANT_ID_y           68774 non-null  float64
#  9   SOURCE_KEY_y         68774 non-null  object
#  10  AMBIENT_TEMPERATURE  68774 non-null  float64
#  11  MODULE_TEMPERATURE   68774 non-null  float64
#  12  IRRADIATION          68774 non-null  float64
#  13  DATE_y               68774 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(8), int64(1), object(2)
# memory usage: 10.4+ MB

# %% [markdown]
# # DAY 9

# %%
#Linear Regression

# %%
r_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68778 entries, 0 to 68777
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            68778 non-null  datetime64[ns]
#  1   PLANT_ID_x           68778 non-null  int64
#  2   SOURCE_KEY_x         68778 non-null  object
#  3   DC_POWER             68778 non-null  float64
#  4   AC_POWER             68778 non-null  float64
#  5   DAILY_YIELD          68778 non-null  float64
#  6   TOTAL_YIELD          68778 non-null  float64
#  7   DATE_x               68778 non-null  datetime64[ns]
#  8   PLANT_ID_y           68774 non-null  float64
#  9   SOURCE_KEY_y         68774 non-null  object
#  10  AMBIENT_TEMPERATURE  68774 non-null  float64
#  11  MODULE_TEMPERATURE   68774 non-null  float64
#  12  IRRADIATION          68774 non-null  float64
#  13  DATE_y               68774 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(8), int64(1), object(2)
# memory usage: 10.4+ MB

# %%
#Linear Regression
# x - inpput    independent variable [irradiation]     12th column  
# y - output     dependent variable [dc power]    3rd column

# %%
#Fill irradiation column with 0 for all null values (NaN and NaT)
r_left['IRRADIATION'] = r_left['IRRADIATION'].fillna(0)
r_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68778 entries, 0 to 68777
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            68778 non-null  datetime64[ns]
#  1   PLANT_ID_x           68778 non-null  int64
#  2   SOURCE_KEY_x         68778 non-null  object
#  3   DC_POWER             68778 non-null  float64
#  4   AC_POWER             68778 non-null  float64
#  5   DAILY_YIELD          68778 non-null  float64
#  6   TOTAL_YIELD          68778 non-null  float64
#  7   DATE_x               68778 non-null  datetime64[ns]
#  8   PLANT_ID_y           68774 non-null  float64
#  9   SOURCE_KEY_y         68774 non-null  object
#  10  AMBIENT_TEMPERATURE  68774 non-null  float64
#  11  MODULE_TEMPERATURE   68774 non-null  float64
#  12  IRRADIATION          68778 non-null  float64
#  13  DATE_y               68774 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(8), int64(1), object(2)
# memory usage: 10.4+ MB

# %%
#x = r_left.iloc[:,[12]].values      #taking all the values of irradiation column
x = r_left.iloc[:,12:13].values
x.ndim
# Out:
# 2

# %%
y = r_left.iloc[:,3].values      #taking all the values of DC_POWER column
y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,s=1)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state=0)

# %%
x_train.shape
# Out:
# (55022, 1)

# %%
x_test.shape
# Out:
# (13756, 1)

# %%
55022+13756
# Out:
# 68778

# %%
y_train.shape
# Out:
# (55022,)

# %%
y_test.shape
# Out:
# (13756,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)      #y_pred is from the ML model of Regression
y_pred
# Out:
# array([  75.70664798, 4754.22735141,   75.70664798, ...,   75.70664798,
#        9527.37447898, 3310.48535178])

# %%
y_test      #y_test is from the output which was given initially (actual)
# Out:
# array([   0.      , 5098.75    ,    0.      , ...,    0.      ,
#        9945.428571, 3503.714286])

# %%
#Visualization  of TRAINING DATA
plt.scatter(x_train,y_train,s=1)
plt.scatter(x_train,model.predict(x_train),s=1)
plt.show()

# %%
#testing data
plt.scatter(x_test,y_test,s=1)
plt.scatter(x_test,model.predict(x_test),s=1)
plt.show()

# %%
plt.scatter(y_pred,y_test,s=1)    #final outcome (actual vs predicted)

# %%
df3 = pd.DataFrame({'Actual':y_test, 'Predicted': y_pred,'Difference in %': ((y_pred-y_test)/(y_test)*100)})
df3
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
#              Actual     Predicted  Difference in %
# 0          0.000000     75.706648              inf
# 1       5098.750000   4754.227351        -6.757002
# 2          0.000000     75.706648              inf
# 3          0.000000     75.706648              inf
# 4          0.000000     75.706648              inf
# ...             ...           ...              ...
# 13751  10889.625000  11167.203341         2.549017
# 13752   9093.125000   8979.260926        -1.252200
# 13753      0.000000     75.706648              inf
# 13754   9945.428571   9527.374479        -4.203480
# 13755   3503.714286   3310.485352        -5.514974
#
# [13756 rows x 3 columns]

# %%
df3.plot()

# %%
#METHOD 1 using sklearn library 
from sklearn.metrics import r2_score,mean_squared_error
print(mean_squared_error(y_pred,y_test))
# Out:
# 348475.8147497292

# %%
#METHOD 2 using numpy (manually finding the value)
import numpy as np 
MSE = np.square(np.subtract(y_pred,y_test)).mean()
MSE
# Out:
# 348475.8147497292

# %%
r2_score(y_pred,y_test)
# Out:
# 0.977832161842473

# %%
#Forecasting

# %%
day_summary = df2.groupby('DATE').agg(TOTAL_IRRADIANCE=('IRRADIATION',sum),DATE=('DATE',max))
day_summary
# Out:
#             TOTAL_IRRADIANCE       DATE
# DATE
# 2020-05-15         19.037010 2020-05-15
# 2020-05-16         18.651690 2020-05-16
# 2020-05-17         22.931378 2020-05-17
# 2020-05-18         15.266485 2020-05-18
# 2020-05-19         18.044861 2020-05-19
# 2020-05-20         18.245542 2020-05-20
# 2020-05-21         23.556170 2020-05-21
# 2020-05-22         22.119123 2020-05-22
# 2020-05-23         26.106652 2020-05-23
# 2020-05-24         24.937180 2020-05-24
# 2020-05-25         27.233366 2020-05-25
# 2020-05-26         24.250589 2020-05-26
# 2020-05-27         20.537566 2020-05-27
# 2020-05-28         26.032384 2020-05-28
# 2020-05-29         24.795661 2020-05-29
# 2020-05-30         21.875054 2020-05-30
# 2020-05-31         17.625458 2020-05-31
# 2020-06-01         17.649244 2020-06-01
# 2020-06-02         21.483649 2020-06-02
# 2020-06-03         21.927709 2020-06-03
# 2020-06-04         24.670974 2020-06-04
# 2020-06-05         23.192659 2020-06-05
# 2020-06-06         19.526878 2020-06-06
# 2020-06-07         24.402373 2020-06-07
# 2020-06-08         25.315527 2020-06-08
# 2020-06-09         24.754673 2020-06-09
# 2020-06-10         19.232292 2020-06-10
# 2020-06-11         15.533706 2020-06-11
# 2020-06-12         16.301551 2020-06-12
# 2020-06-13         25.389355 2020-06-13
# 2020-06-14         21.128221 2020-06-14
# 2020-06-15         19.768806 2020-06-15
# 2020-06-16         17.979125 2020-06-16
# 2020-06-17         16.988513 2020-06-17

# %%
# datetime DATE ds   TOTAL_IRRADIANCE  y
day_summary = day_summary.rename(columns={'DATE':'ds', 'TOTAL_IRRADIANCE':'y'})
day_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 34 entries, 2020-05-15 to 2020-06-17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       34 non-null     float64
#  1   ds      34 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 816.0 bytes

# %%
#importting fbprophet
#to avoid to overfitting or underfitting of the model we use changepoint_proir_scale
import fbprophet
op = fbprophet.Prophet(changepoint_prior_scale=0.25)    #changepoint_prior_scale to avoid underfit or overfitting of the model
op.fit(day_summary)

# %%
#make a future possible prediction[DATAFRAME] for 1month(period) freq D-days
forecast = op.make_future_dataframe(periods = 30, freq ='D')
forecast = op.predict(forecast)

# %%
op.plot(forecast, xlabel ='Date', ylabel = 'IRRADIATION')
plt.title("Irradiation Prediction")    #this line is best fit line    #light blue gradient borders or extremes
# Out:
# Text(0.5, 1.0, 'Irradiation Prediction')

# %%
#new dataframe for hours
df_new = df2[['DATE_TIME','IRRADIATION']]
df_new
# Out:
#                DATE_TIME  IRRADIATION
# 0    2020-05-15 00:00:00          0.0
# 1    2020-05-15 00:15:00          0.0
# 2    2020-05-15 00:30:00          0.0
# 3    2020-05-15 00:45:00          0.0
# 4    2020-05-15 01:00:00          0.0
# ...                  ...          ...
# 3177 2020-06-17 22:45:00          0.0
# 3178 2020-06-17 23:00:00          0.0
# 3179 2020-06-17 23:15:00          0.0
# 3180 2020-06-17 23:30:00          0.0
# 3181 2020-06-17 23:45:00          0.0
#
# [3182 rows x 2 columns]

# %%
df_new = df_new.rename(columns = {'DATE_TIME':'ds','IRRADIATION':'y'})
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      3182 non-null   datetime64[ns]
#  1   y       3182 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 49.8 KB

# %%
import fbprophet
op = fbprophet.Prophet(changepoint_prior_scale=0.25)
op.fit(df_new)

# %%
forecast = op.make_future_dataframe(periods=300, freq = 'H')
forecast = op.predict(forecast)

# %%
op.plot(forecast, xlabel='Date',ylabel='Irradiation',figsize=(20,10))
plt.title('Irradiation Prediction')   #if you get two plots, add a semicolon at the end of this line
# Out:
# Text(0.5, 1.0, 'Irradiation Prediction')

# %%
op.plot_components(forecast);

# %%
forecast
# Out:
#                       ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 0    2020-05-15 00:00:00  0.205300   -0.162085    0.104951     0.205300
# 1    2020-05-15 00:15:00  0.205219   -0.176553    0.096107     0.205219
# 2    2020-05-15 00:30:00  0.205139   -0.158445    0.102101     0.205139
# 3    2020-05-15 00:45:00  0.205059   -0.168675    0.097215     0.205059
# 4    2020-05-15 01:00:00  0.204978   -0.157604    0.100859     0.204978
# ...                  ...       ...         ...         ...          ...
# 3477 2020-06-30 07:45:00  0.194875   -0.192738    0.650369    -0.220317
# 3478 2020-06-30 08:45:00  0.194863   -0.027016    0.836062    -0.222041
# 3479 2020-06-30 09:45:00  0.194851    0.148846    0.987005    -0.222829
# 3480 2020-06-30 10:45:00  0.194838    0.212625    1.092505    -0.226079
# 3481 2020-06-30 11:45:00  0.194826    0.274934    1.136701    -0.229944
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0        0.205300       -0.240835             -0.240835             -0.240835
# 1        0.205219       -0.241011             -0.241011             -0.241011
# 2        0.205139       -0.240314             -0.240314             -0.240314
# 3        0.205059       -0.238811             -0.238811             -0.238811
# 4        0.204978       -0.236650             -0.236650             -0.236650
# ...           ...             ...                   ...                   ...
# 3477     0.611137        0.022688              0.022688              0.022688
# 3478     0.613360        0.199631              0.199631              0.199631
# 3479     0.615582        0.357320              0.357320              0.357320
# 3480     0.617803        0.463611              0.463611              0.463611
# 3481     0.619980        0.509700              0.509700              0.509700
#
#          daily  daily_lower  daily_upper    weekly  weekly_lower  \
# 0    -0.234161    -0.234161    -0.234161 -0.006674     -0.006674
# 1    -0.234281    -0.234281    -0.234281 -0.006730     -0.006730
# 2    -0.233527    -0.233527    -0.233527 -0.006786     -0.006786
# 3    -0.231967    -0.231967    -0.231967 -0.006844     -0.006844
# 4    -0.229748    -0.229748    -0.229748 -0.006902     -0.006902
# ...        ...          ...          ...       ...           ...
# 3477  0.023535     0.023535     0.023535 -0.000848     -0.000848
# 3478  0.200955     0.200955     0.200955 -0.001324     -0.001324
# 3479  0.359161     0.359161     0.359161 -0.001841     -0.001841
# 3480  0.466009     0.466009     0.466009 -0.002398     -0.002398
# 3481  0.512692     0.512692     0.512692 -0.002992     -0.002992
#
#       weekly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        -0.006674                   0.0                         0.0
# 1        -0.006730                   0.0                         0.0
# 2        -0.006786                   0.0                         0.0
# 3        -0.006844                   0.0                         0.0
# 4        -0.006902                   0.0                         0.0
# ...            ...                   ...                         ...
# 3477     -0.000848                   0.0                         0.0
# 3478     -0.001324                   0.0                         0.0
# 3479     -0.001841                   0.0                         0.0
# 3480     -0.002398                   0.0                         0.0
# 3481     -0.002992                   0.0                         0.0
#
#       multiplicative_terms_upper      yhat
# 0                            0.0 -0.035536
# 1                            0.0 -0.035792
# 2                            0.0 -0.035175
# 3                            0.0 -0.033752
# 4                            0.0 -0.031672
# ...                          ...       ...
# 3477                         0.0  0.217563
# 3478                         0.0  0.394494
# 3479                         0.0  0.552171
# 3480                         0.0  0.658450
# 3481                         0.0  0.704526
#
# [3482 rows x 19 columns]
